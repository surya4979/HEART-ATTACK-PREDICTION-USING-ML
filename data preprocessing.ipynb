# %% [markdown]
# # data pre processing

# %%
#import library packages
import numpy as n
import pandas as p

# %%
data =p.read_csv('C:/Users/Surya/OneDrive/Desktop/pro/data/heart.csv')

# %%
data1=p.read_csv(r'C:\Users\Surya\OneDrive\Desktop\pro\data\heart.csv')

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52  1.0   0       125   212    0        1      168      0      1.0      2
# 1   53  1.0   0       140   203    1        0      155      1      3.1      0
# 2   70  NaN   0       145   174    0        1      125      1      2.6      0
# 3   61  1.0   0       148   203    0        1      161      0      0.0      2
# 4   62  0.0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59  1.0   1       140   221    0        1      164      1      0.0
# 1021   60  1.0   0       125   258    0        0      141      1      2.8
# 1022   47  1.0   0       110   275    0        0      118      1      1.0
# 1023   50  0.0   0       110   254    0        0      159      0      0.0
# 1024   54  1.0   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52  1.0   0       125   212    0        1      168      0      1.0
# 1      53  1.0   0       140   203    1        0      155      1      3.1
# 2      70  NaN   0       145   174    0        1      125      1      2.6
# 3      61  1.0   0       148   203    0        1      161      0      0.0
# 4      62  0.0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59  1.0   1       140   221    0        1      164      1      0.0
# 1021   60  1.0   0       125   258    0        0      141      1      2.8
# 1022   47  1.0   0       110   275    0        0      118      1      1.0
# 1023   50  0.0   0       110   254    0        0      159      0      0.0
# 1024   54  1.0   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1024 non-null   float64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 112.2 KB

# %%
#drop nan values only
su = data.dropna()

# %%
su.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1024 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1024 non-null   int64
#  1   sex       1024 non-null   float64
#  2   cp        1024 non-null   int64
#  3   trestbps  1024 non-null   int64
#  4   chol      1024 non-null   int64
#  5   fbs       1024 non-null   int64
#  6   restecg   1024 non-null   int64
#  7   thalach   1024 non-null   int64
#  8   exang     1024 non-null   int64
#  9   oldpeak   1024 non-null   float64
#  10  slope     1024 non-null   int64
#  11  ca        1024 non-null   int64
#  12  thal      1024 non-null   int64
#  13  target    1024 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 120.0 KB

# %%
su.shape
# Out:
# (1024, 14)

# %%
su.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  1024.000000  1024.000000  1024.000000  1024.000000  1024.000000
# mean     54.418945     0.695312     0.943359   131.598633   246.070312
# std       9.063654     0.460500     1.029722    17.520273    51.568563
# min      29.000000     0.000000     0.000000    94.000000   126.000000
# 25%      48.000000     0.000000     0.000000   120.000000   211.000000
# 50%      56.000000     1.000000     1.000000   130.000000   240.000000
# 75%      61.000000     1.000000     2.000000   140.000000   275.000000
# max      77.000000     1.000000     3.000000   200.000000   564.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1024.000000  1024.000000  1024.000000  1024.000000  1024.000000
# mean      0.149414     0.529297   149.137695     0.335938     1.070020
# std       0.356670     0.527931    23.004602     0.472548     1.174655
# ...

# %%
su.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52  1.0   0       125   212    0        1      168      0      1.0
# 1      53  1.0   0       140   203    1        0      155      1      3.1
# 3      61  1.0   0       148   203    0        1      161      0      0.0
# 4      62  0.0   0       138   294    1        1      106      0      1.9
# 5      58  0.0   0       100   248    0        0      122      0      1.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59  1.0   1       140   221    0        1      164      1      0.0
# 1021   60  1.0   0       125   258    0        0      141      1      2.8
# 1022   47  1.0   0       110   275    0        0      118      1      1.0
# 1023   50  0.0   0       110   254    0        0      159      0      0.0
# 1024   54  1.0   0       120   188    0        1      113      0      1.4
#
# ...

# %%
su.age.unique()
# Out:
# array([52, 53, 61, 62, 58, 55, 46, 54, 71, 43, 34, 51, 50, 60, 67, 45, 63,
#        42, 44, 56, 57, 70, 59, 64, 65, 41, 66, 38, 49, 48, 29, 37, 47, 68,
#        76, 40, 39, 77, 69, 35, 74], dtype=int64)

# %%
su.sex.unique()
# Out:
# array([1., 0.])

# %%
su.duplicated()
# Out:
# 0       False
# 1       False
# 3       False
# 4       False
# 5       False
#         ...
# 1020     True
# 1021     True
# 1022     True
# 1023     True
# 1024     True
# Length: 1024, dtype: bool

# %%
sum(su.duplicated())
# Out:
# 722

# %%
su.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
p.Categorical(su['sex']).describe()
# Out:
#             counts     freqs
# categories
# 0.0            312  0.304688
# 1.0            712  0.695312

# %%
p.Categorical(su['target']).describe()
# Out:
#             counts     freqs
# categories
# 0              498  0.486328
# 1              526  0.513672

# %%
p.Categorical(su['chol']).describe()
# Out:
#             counts     freqs
# categories
# 126              3  0.002930
# 131              3  0.002930
# 141              3  0.002930
# 149              8  0.007812
# 157              4  0.003906
# ...            ...       ...
# 394              3  0.002930
# 407              4  0.003906
# 409              3  0.002930
# 417              3  0.002930
# 564              3  0.002930
#
# [152 rows x 2 columns]

# %%
su['sex'].value_counts()
# Out:
# sex
# 1.0    712
# 0.0    312
# Name: count, dtype: int64

# %%
su['cp'].value_counts()
# Out:
# cp
# 0    496
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
su.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.104522 -0.070562  0.270306  0.222696  0.122132
# sex      -0.104522  1.000000 -0.040553 -0.079507 -0.197586  0.027479
# cp       -0.070562 -0.040553  1.000000  0.038888 -0.083003  0.078958
# trestbps  0.270306 -0.079507  0.038888  1.000000  0.129180  0.182147
# chol      0.222696 -0.197586 -0.083003  0.129180  1.000000  0.026373
# fbs       0.122132  0.027479  0.078958  0.182147  0.026373  1.000000
# restecg  -0.134436 -0.055726  0.044413 -0.124544 -0.146391 -0.103736
# thalach  -0.389238 -0.048724  0.306191 -0.038513 -0.023237 -0.009301
# exang     0.086016  0.138413 -0.400807  0.060224  0.069429  0.049887
# oldpeak   0.206423  0.083933 -0.173785  0.186670  0.066774  0.011402
# slope    -0.165991 -0.025284  0.129999 -0.119097 -0.017366 -0.062981
# ca        0.273242  0.112255 -0.176980  0.105158  0.073350  0.136904
# thal      0.070613  0.197877 -0.162528  0.058513  0.101886 -0.041759
# ...

# %%
import numpy

speed = [ 86,87,88,86,87,85,86]

x = numpy.mean(speed)

print(x)
# Out:
# 86.42857142857143

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)
# Out:
# 87.0

# %%
print(len(speed))
# Out:
# 13

# %%
from scipy import stats

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = stats.mode(speed)

print(x)
# Out:
# ModeResult(mode=86, count=3)

# %%
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages,75)

print(x)
# Out:
# 43.0

# %%
x = numpy.percentile(ages,25)

print(x)
# Out:
# 11.0

# %%
import numpy
x = numpy.random.uniform(0.0,5.0,250)
print(x)
# Out:
# [1.91269885 2.67286833 4.09768783 1.26735788 1.50292152 1.79708503
#  2.17915671 1.35410015 0.4062578  2.39824393 2.62205195 1.83582875
#  0.02620264 2.45164464 0.89710685 3.97467187 1.96318505 4.6994769
#  0.63053335 2.28143816 2.61365415 0.02999111 4.51290883 1.32807159
#  4.61155021 0.8675152  1.3834914  4.65722878 1.56949136 2.42709375
#  0.30773703 1.97355238 1.09864682 3.34364847 3.55255385 4.15415998
#  3.32895123 2.11094877 4.55802936 2.29908785 4.96153793 1.31680318
#  4.78463628 3.61713273 0.91032847 2.45014066 3.26643747 4.8221578
#  0.7063031  2.75360883 2.89317235 0.15443277 1.49841512 4.47459444
#  0.35961391 0.70711414 2.49853117 1.50147056 4.78611261 4.04598233
#  3.9260107  4.74909301 0.55503269 3.27960919 3.17410055 1.11164932
#  3.12150463 1.6287011  1.88183837 2.39124692 0.94294655 1.8924472
#  1.61723591 3.65705655 3.54818983 3.95608409 1.70154562 0.08048708
#  2.4559373  2.82226772 2.17635051 4.36199635 0.36015526 1.51303816
# ...

# %%
import numpy
import matplotlib.pyplot as plt
#using uniform()methods

x = numpy.random.uniform(-5,5,1000)
plt.hist(x, bins=50, density= True)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
#using uniform()methods

x = numpy.random.uniform(0.0,5.0,250)
plt.hist(x,5)
plt.show()

# %%
# three lines to make our compiler able to draw:
import  numpy
import sys
import matplotlib
matplotlib. use ('Agg')
import matplotlib.pyplot as plt
x = numpy.random.normal(5,10,5000)
plt.hist(x,10)
plt.show()
# two lines to make our compiler able to draw:
#plt.savefig(sys.stdout.buffer)
#sys.stdout.flush()
